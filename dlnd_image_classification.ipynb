# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 2
sample_id = 3
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 2:
# Samples: 10000
# Label Counts: {0: 984, 1: 1007, 2: 1010, 3: 995, 4: 1010, 5: 988, 6: 1008, 7: 1026, 8: 987, 9: 985}
# First 20 Labels: [1, 6, 6, 8, 8, 3, 4, 6, 0, 6, 0, 3, 6, 6, 5, 4, 8, 3, 2, 6]
#
# Example of Image 3:
# Image - Min Value: 4 Max Value: 255
# Image - Shape: (32, 32, 3)
# Label - Label Id: 8 Name: ship

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    a = 0
    b = 1
    grayscale_min = 0
    grayscale_max = 255
    return a + (((x - grayscale_min)*(b-a)) / (grayscale_max - grayscale_min))


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
import tensorflow as tf
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    return tf.Session().run(tf.one_hot(x, 10))


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a bach of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    features = tf.placeholder(tf.float32, tuple([None] + list(image_shape)), 'x')
    return features


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    labels = tf.placeholder(tf.float32, (None, n_classes), 'y')
    return labels


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    prob = tf.placeholder(tf.float32, None, name="keep_prob")
    return prob


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    input_shape = list(conv_ksize + (x_tensor.get_shape().as_list()[-1], ) + (conv_num_outputs, ))
    weights = tf.Variable(tf.truncated_normal(input_shape, 0, 0.1)) 
    bias = tf.Variable(tf.zeros(conv_num_outputs))
    
    conv_layer = tf.nn.conv2d(x_tensor, weights, [1, ] + list(conv_strides) + [1, ], padding='SAME')
    conv_layer = tf.nn.bias_add(conv_layer, bias)
    conv_layer = tf.nn.relu(conv_layer)
    
    # Apply Max Pooling
    conv_layer = tf.nn.max_pool(conv_layer, 
                                [1, ] + list(pool_ksize) + [1, ], 
                                [1, ] + list(pool_strides) + [1, ], 
                                padding='SAME')
    
    return conv_layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
from numpy import prod
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    shape = x_tensor.get_shape().as_list()
    dimension = prod(shape[1:])
    return tf.reshape(x_tensor, [-1, ] + [dimension, ])

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    input_shape = [x_tensor.get_shape().as_list()[-1], ] + [num_outputs, ]
    weights = tf.Variable(tf.truncated_normal(input_shape, 0, 0.1)) 
    bias = tf.Variable(tf.zeros(num_outputs))
    
    fully_conn = tf.add(tf.matmul(x_tensor, weights), bias)
    return tf.nn.relu(fully_conn)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    input_shape = [x_tensor.get_shape().as_list()[-1], ] + [num_outputs, ]
    weights = tf.Variable(tf.truncated_normal(input_shape, 0, 0.1))
    bias = tf.Variable(tf.zeros(num_outputs))
    
    out = tf.add(tf.matmul(x_tensor, weights), bias)
    return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    conv = conv2d_maxpool(x, conv_num_outputs=20, conv_ksize=(4, 4), conv_strides=(1, 1), pool_ksize=(8, 8), pool_strides=(1, 1))
    conv = tf.nn.dropout(conv, keep_prob)

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    conv = flatten(conv)

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    fc = fully_conn(conv, 400)
    fc = tf.nn.dropout(fc, keep_prob)
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    out = output(fc, 10)
    
    # TODO: return output
    return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer, feed_dict={
        x: feature_batch,
        y: label_batch,
        keep_prob: keep_probability
    })


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    loss = session.run(cost, feed_dict={
        x: feature_batch,
        y: label_batch,
        keep_prob: 1.0
    })
    valid_acc = session.run(accuracy, feed_dict={
        x: valid_features,
        y: valid_labels,
        keep_prob: 1.
    })
    print('Loss: {:>10.4f} Validation Accuracy: {:.6f}'.format(loss, valid_acc))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 100
batch_size = 128
keep_probability = 0.3

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Loss:     2.2351 Validation Accuracy: 0.241600
# Epoch  2, CIFAR-10 Batch 1:  Loss:     1.9592 Validation Accuracy: 0.349600
# Epoch  3, CIFAR-10 Batch 1:  Loss:     1.8397 Validation Accuracy: 0.403400
# Epoch  4, CIFAR-10 Batch 1:  Loss:     1.6970 Validation Accuracy: 0.427000
# Epoch  5, CIFAR-10 Batch 1:  Loss:     1.6194 Validation Accuracy: 0.452600
# Epoch  6, CIFAR-10 Batch 1:  Loss:     1.4794 Validation Accuracy: 0.463200
# Epoch  7, CIFAR-10 Batch 1:  Loss:     1.4645 Validation Accuracy: 0.483200
# Epoch  8, CIFAR-10 Batch 1:  Loss:     1.3638 Validation Accuracy: 0.492800
# Epoch  9, CIFAR-10 Batch 1:  Loss:     1.2871 Validation Accuracy: 0.494600
# Epoch 10, CIFAR-10 Batch 1:  Loss:     1.2513 Validation Accuracy: 0.505200
# Epoch 11, CIFAR-10 Batch 1:  Loss:     1.1903 Validation Accuracy: 0.509600
# Epoch 12, CIFAR-10 Batch 1:  Loss:     1.1499 Validation Accuracy: 0.518000
# Epoch 13, CIFAR-10 Batch 1:  Loss:     1.0917 Validation Accuracy: 0.522000
# Epoch 14, CIFAR-10 Batch 1:  Loss:     1.1139 Validation Accuracy: 0.541800
# Epoch 15, CIFAR-10 Batch 1:  Loss:     0.9964 Validation Accuracy: 0.540400
# Epoch 16, CIFAR-10 Batch 1:  Loss:     0.9986 Validation Accuracy: 0.544200
# Epoch 17, CIFAR-10 Batch 1:  Loss:     0.9598 Validation Accuracy: 0.546800
# Epoch 18, CIFAR-10 Batch 1:  Loss:     0.8820 Validation Accuracy: 0.538400
# Epoch 19, CIFAR-10 Batch 1:  Loss:     0.8323 Validation Accuracy: 0.560600
# Epoch 20, CIFAR-10 Batch 1:  Loss:     0.8315 Validation Accuracy: 0.562600
# Epoch 21, CIFAR-10 Batch 1:  Loss:     0.8315 Validation Accuracy: 0.551200
# Epoch 22, CIFAR-10 Batch 1:  Loss:     0.8048 Validation Accuracy: 0.563400
# Epoch 23, CIFAR-10 Batch 1:  Loss:     0.7387 Validation Accuracy: 0.563600
# Epoch 24, CIFAR-10 Batch 1:  Loss:     0.7076 Validation Accuracy: 0.559000
# Epoch 25, CIFAR-10 Batch 1:  Loss:     0.6911 Validation Accuracy: 0.569800
# Epoch 26, CIFAR-10 Batch 1:  Loss:     0.6417 Validation Accuracy: 0.577000
# Epoch 27, CIFAR-10 Batch 1:  Loss:     0.6570 Validation Accuracy: 0.567800
# Epoch 28, CIFAR-10 Batch 1:  Loss:     0.6093 Validation Accuracy: 0.567200
# Epoch 29, CIFAR-10 Batch 1:  Loss:     0.6108 Validation Accuracy: 0.584400
# Epoch 30, CIFAR-10 Batch 1:  Loss:     0.6102 Validation Accuracy: 0.579200
# Epoch 31, CIFAR-10 Batch 1:  Loss:     0.5484 Validation Accuracy: 0.584400
# Epoch 32, CIFAR-10 Batch 1:  Loss:     0.5600 Validation Accuracy: 0.585200
# Epoch 33, CIFAR-10 Batch 1:  Loss:     0.5834 Validation Accuracy: 0.569000
# Epoch 34, CIFAR-10 Batch 1:  Loss:     0.5277 Validation Accuracy: 0.584600
# Epoch 35, CIFAR-10 Batch 1:  Loss:     0.4716 Validation Accuracy: 0.594400
# Epoch 36, CIFAR-10 Batch 1:  Loss:     0.4814 Validation Accuracy: 0.571600
# Epoch 37, CIFAR-10 Batch 1:  Loss:     0.4896 Validation Accuracy: 0.588200
# Epoch 38, CIFAR-10 Batch 1:  Loss:     0.4751 Validation Accuracy: 0.585400
# Epoch 39, CIFAR-10 Batch 1:  Loss:     0.4056 Validation Accuracy: 0.599200
# Epoch 40, CIFAR-10 Batch 1:  Loss:     0.3978 Validation Accuracy: 0.598200
# Epoch 41, CIFAR-10 Batch 1:  Loss:     0.3797 Validation Accuracy: 0.588200
# Epoch 42, CIFAR-10 Batch 1:  Loss:     0.3775 Validation Accuracy: 0.597000
# Epoch 43, CIFAR-10 Batch 1:  Loss:     0.3714 Validation Accuracy: 0.593400
# Epoch 44, CIFAR-10 Batch 1:  Loss:     0.3522 Validation Accuracy: 0.600800
# Epoch 45, CIFAR-10 Batch 1:  Loss:     0.3061 Validation Accuracy: 0.611200
# Epoch 46, CIFAR-10 Batch 1:  Loss:     0.3081 Validation Accuracy: 0.602800
# Epoch 47, CIFAR-10 Batch 1:  Loss:     0.2844 Validation Accuracy: 0.604400
# Epoch 48, CIFAR-10 Batch 1:  Loss:     0.2712 Validation Accuracy: 0.599600
# Epoch 49, CIFAR-10 Batch 1:  Loss:     0.3361 Validation Accuracy: 0.585200
# Epoch 50, CIFAR-10 Batch 1:  Loss:     0.2405 Validation Accuracy: 0.606000
# Epoch 51, CIFAR-10 Batch 1:  Loss:     0.2175 Validation Accuracy: 0.611800
# Epoch 52, CIFAR-10 Batch 1:  Loss:     0.2015 Validation Accuracy: 0.603200
# Epoch 53, CIFAR-10 Batch 1:  Loss:     0.2203 Validation Accuracy: 0.614000
# Epoch 54, CIFAR-10 Batch 1:  Loss:     0.2194 Validation Accuracy: 0.612000
# Epoch 55, CIFAR-10 Batch 1:  Loss:     0.1808 Validation Accuracy: 0.606400
# Epoch 56, CIFAR-10 Batch 1:  Loss:     0.1731 Validation Accuracy: 0.615400
# Epoch 57, CIFAR-10 Batch 1:  Loss:     0.1689 Validation Accuracy: 0.610600
# Epoch 58, CIFAR-10 Batch 1:  Loss:     0.1751 Validation Accuracy: 0.614200
# Epoch 59, CIFAR-10 Batch 1:  Loss:     0.1455 Validation Accuracy: 0.620200
# Epoch 60, CIFAR-10 Batch 1:  Loss:     0.1501 Validation Accuracy: 0.619600
# Epoch 61, CIFAR-10 Batch 1:  Loss:     0.1459 Validation Accuracy: 0.611600
# Epoch 62, CIFAR-10 Batch 1:  Loss:     0.1482 Validation Accuracy: 0.605600
# Epoch 63, CIFAR-10 Batch 1:  Loss:     0.1342 Validation Accuracy: 0.606200
# Epoch 64, CIFAR-10 Batch 1:  Loss:     0.1378 Validation Accuracy: 0.603000
# Epoch 65, CIFAR-10 Batch 1:  Loss:     0.1175 Validation Accuracy: 0.604400
# Epoch 66, CIFAR-10 Batch 1:  Loss:     0.1012 Validation Accuracy: 0.610000
# Epoch 67, CIFAR-10 Batch 1:  Loss:     0.1194 Validation Accuracy: 0.612600
# Epoch 68, CIFAR-10 Batch 1:  Loss:     0.1056 Validation Accuracy: 0.603800
# Epoch 69, CIFAR-10 Batch 1:  Loss:     0.1091 Validation Accuracy: 0.612400
# Epoch 70, CIFAR-10 Batch 1:  Loss:     0.1124 Validation Accuracy: 0.612000
# Epoch 71, CIFAR-10 Batch 1:  Loss:     0.1022 Validation Accuracy: 0.608200
# Epoch 72, CIFAR-10 Batch 1:  Loss:     0.0842 Validation Accuracy: 0.613200
# Epoch 73, CIFAR-10 Batch 1:  Loss:     0.0817 Validation Accuracy: 0.600800
# Epoch 74, CIFAR-10 Batch 1:  Loss:     0.0800 Validation Accuracy: 0.613000
# Epoch 75, CIFAR-10 Batch 1:  Loss:     0.0792 Validation Accuracy: 0.611000
# Epoch 76, CIFAR-10 Batch 1:  Loss:     0.0630 Validation Accuracy: 0.614200
# Epoch 77, CIFAR-10 Batch 1:  Loss:     0.0622 Validation Accuracy: 0.610200
# Epoch 78, CIFAR-10 Batch 1:  Loss:     0.0776 Validation Accuracy: 0.617800
# Epoch 79, CIFAR-10 Batch 1:  Loss:     0.0631 Validation Accuracy: 0.612800
# Epoch 80, CIFAR-10 Batch 1:  Loss:     0.0743 Validation Accuracy: 0.610600
# Epoch 81, CIFAR-10 Batch 1:  Loss:     0.0656 Validation Accuracy: 0.602400
# Epoch 82, CIFAR-10 Batch 1:  Loss:     0.0574 Validation Accuracy: 0.605600
# Epoch 83, CIFAR-10 Batch 1:  Loss:     0.0604 Validation Accuracy: 0.606800
# Epoch 84, CIFAR-10 Batch 1:  Loss:     0.0439 Validation Accuracy: 0.611000
# Epoch 85, CIFAR-10 Batch 1:  Loss:     0.0519 Validation Accuracy: 0.613600
# Epoch 86, CIFAR-10 Batch 1:  Loss:     0.0523 Validation Accuracy: 0.608800
# Epoch 87, CIFAR-10 Batch 1:  Loss:     0.0501 Validation Accuracy: 0.617400
# Epoch 88, CIFAR-10 Batch 1:  Loss:     0.0467 Validation Accuracy: 0.601400
# Epoch 89, CIFAR-10 Batch 1:  Loss:     0.0448 Validation Accuracy: 0.615200
# Epoch 90, CIFAR-10 Batch 1:  Loss:     0.0504 Validation Accuracy: 0.612200
# Epoch 91, CIFAR-10 Batch 1:  Loss:     0.0521 Validation Accuracy: 0.619200
# Epoch 92, CIFAR-10 Batch 1:  Loss:     0.0374 Validation Accuracy: 0.609000
# Epoch 93, CIFAR-10 Batch 1:  Loss:     0.0427 Validation Accuracy: 0.607200
# Epoch 94, CIFAR-10 Batch 1:  Loss:     0.0429 Validation Accuracy: 0.616800
# Epoch 95, CIFAR-10 Batch 1:  Loss:     0.0408 Validation Accuracy: 0.614200
# Epoch 96, CIFAR-10 Batch 1:  Loss:     0.0486 Validation Accuracy: 0.617200
# Epoch 97, CIFAR-10 Batch 1:  Loss:     0.0299 Validation Accuracy: 0.622400
# Epoch 98, CIFAR-10 Batch 1:  Loss:     0.0465 Validation Accuracy: 0.600400
# Epoch 99, CIFAR-10 Batch 1:  Loss:     0.0318 Validation Accuracy: 0.608400
# Epoch 100, CIFAR-10 Batch 1:  Loss:     0.0264 Validation Accuracy: 0.618200

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Loss:     2.2362 Validation Accuracy: 0.212400
# Epoch  1, CIFAR-10 Batch 2:  Loss:     1.9175 Validation Accuracy: 0.356600
# Epoch  1, CIFAR-10 Batch 3:  Loss:     1.7286 Validation Accuracy: 0.380200
# Epoch  1, CIFAR-10 Batch 4:  Loss:     1.7148 Validation Accuracy: 0.422200
# Epoch  1, CIFAR-10 Batch 5:  Loss:     1.6247 Validation Accuracy: 0.434200
# Epoch  2, CIFAR-10 Batch 1:  Loss:     1.6701 Validation Accuracy: 0.441600
# Epoch  2, CIFAR-10 Batch 2:  Loss:     1.5988 Validation Accuracy: 0.473400
# Epoch  2, CIFAR-10 Batch 3:  Loss:     1.4190 Validation Accuracy: 0.458800
# Epoch  2, CIFAR-10 Batch 4:  Loss:     1.5859 Validation Accuracy: 0.486400
# Epoch  2, CIFAR-10 Batch 5:  Loss:     1.4580 Validation Accuracy: 0.488800
# Epoch  3, CIFAR-10 Batch 1:  Loss:     1.5218 Validation Accuracy: 0.495600
# Epoch  3, CIFAR-10 Batch 2:  Loss:     1.3187 Validation Accuracy: 0.502000
# Epoch  3, CIFAR-10 Batch 3:  Loss:     1.2600 Validation Accuracy: 0.514600
# Epoch  3, CIFAR-10 Batch 4:  Loss:     1.4642 Validation Accuracy: 0.515000
# Epoch  3, CIFAR-10 Batch 5:  Loss:     1.3611 Validation Accuracy: 0.507600
# Epoch  4, CIFAR-10 Batch 1:  Loss:     1.3545 Validation Accuracy: 0.533400
# Epoch  4, CIFAR-10 Batch 2:  Loss:     1.3027 Validation Accuracy: 0.536800
# Epoch  4, CIFAR-10 Batch 3:  Loss:     1.1424 Validation Accuracy: 0.531600
# Epoch  4, CIFAR-10 Batch 4:  Loss:     1.3476 Validation Accuracy: 0.546200
# Epoch  4, CIFAR-10 Batch 5:  Loss:     1.2418 Validation Accuracy: 0.545200
# Epoch  5, CIFAR-10 Batch 1:  Loss:     1.2644 Validation Accuracy: 0.547800
# Epoch  5, CIFAR-10 Batch 2:  Loss:     1.2368 Validation Accuracy: 0.549800
# Epoch  5, CIFAR-10 Batch 3:  Loss:     1.0563 Validation Accuracy: 0.550400
# Epoch  5, CIFAR-10 Batch 4:  Loss:     1.2660 Validation Accuracy: 0.566200
# Epoch  5, CIFAR-10 Batch 5:  Loss:     1.1738 Validation Accuracy: 0.558000
# Epoch  6, CIFAR-10 Batch 1:  Loss:     1.2139 Validation Accuracy: 0.569200
# Epoch  6, CIFAR-10 Batch 2:  Loss:     1.0886 Validation Accuracy: 0.557800
# Epoch  6, CIFAR-10 Batch 3:  Loss:     1.0619 Validation Accuracy: 0.570000
# Epoch  6, CIFAR-10 Batch 4:  Loss:     1.2379 Validation Accuracy: 0.574200
# Epoch  6, CIFAR-10 Batch 5:  Loss:     1.0839 Validation Accuracy: 0.580200
# Epoch  7, CIFAR-10 Batch 1:  Loss:     1.1763 Validation Accuracy: 0.580400
# Epoch  7, CIFAR-10 Batch 2:  Loss:     1.0345 Validation Accuracy: 0.575000
# Epoch  7, CIFAR-10 Batch 3:  Loss:     1.0254 Validation Accuracy: 0.575800
# Epoch  7, CIFAR-10 Batch 4:  Loss:     1.2363 Validation Accuracy: 0.563800
# Epoch  7, CIFAR-10 Batch 5:  Loss:     1.0577 Validation Accuracy: 0.588400
# Epoch  8, CIFAR-10 Batch 1:  Loss:     1.1224 Validation Accuracy: 0.582800
# Epoch  8, CIFAR-10 Batch 2:  Loss:     1.0657 Validation Accuracy: 0.594200
# Epoch  8, CIFAR-10 Batch 3:  Loss:     0.9432 Validation Accuracy: 0.569200
# Epoch  8, CIFAR-10 Batch 4:  Loss:     1.1524 Validation Accuracy: 0.594400
# Epoch  8, CIFAR-10 Batch 5:  Loss:     1.0524 Validation Accuracy: 0.586600
# Epoch  9, CIFAR-10 Batch 1:  Loss:     1.1464 Validation Accuracy: 0.599600
# Epoch  9, CIFAR-10 Batch 2:  Loss:     0.9793 Validation Accuracy: 0.605200
# Epoch  9, CIFAR-10 Batch 3:  Loss:     0.9478 Validation Accuracy: 0.592000
# Epoch  9, CIFAR-10 Batch 4:  Loss:     1.1361 Validation Accuracy: 0.603000
# Epoch  9, CIFAR-10 Batch 5:  Loss:     1.0669 Validation Accuracy: 0.604400
# Epoch 10, CIFAR-10 Batch 1:  Loss:     1.0384 Validation Accuracy: 0.613200
# Epoch 10, CIFAR-10 Batch 2:  Loss:     0.9621 Validation Accuracy: 0.614400
# Epoch 10, CIFAR-10 Batch 3:  Loss:     0.8968 Validation Accuracy: 0.607600
# Epoch 10, CIFAR-10 Batch 4:  Loss:     1.1370 Validation Accuracy: 0.616000
# Epoch 10, CIFAR-10 Batch 5:  Loss:     0.9831 Validation Accuracy: 0.606800
# Epoch 11, CIFAR-10 Batch 1:  Loss:     0.9780 Validation Accuracy: 0.621400
# Epoch 11, CIFAR-10 Batch 2:  Loss:     0.9706 Validation Accuracy: 0.616800
# Epoch 11, CIFAR-10 Batch 3:  Loss:     0.8393 Validation Accuracy: 0.613200
# Epoch 11, CIFAR-10 Batch 4:  Loss:     1.0336 Validation Accuracy: 0.621800
# Epoch 11, CIFAR-10 Batch 5:  Loss:     0.9286 Validation Accuracy: 0.614400
# Epoch 12, CIFAR-10 Batch 1:  Loss:     0.9178 Validation Accuracy: 0.627000
# Epoch 12, CIFAR-10 Batch 2:  Loss:     0.8859 Validation Accuracy: 0.613400
# Epoch 12, CIFAR-10 Batch 3:  Loss:     0.8199 Validation Accuracy: 0.626200
# Epoch 12, CIFAR-10 Batch 4:  Loss:     0.9833 Validation Accuracy: 0.623600
# Epoch 12, CIFAR-10 Batch 5:  Loss:     0.9112 Validation Accuracy: 0.621200
# Epoch 13, CIFAR-10 Batch 1:  Loss:     0.9252 Validation Accuracy: 0.635000
# Epoch 13, CIFAR-10 Batch 2:  Loss:     0.7638 Validation Accuracy: 0.630000
# Epoch 13, CIFAR-10 Batch 3:  Loss:     0.8102 Validation Accuracy: 0.620000
# Epoch 13, CIFAR-10 Batch 4:  Loss:     0.9366 Validation Accuracy: 0.637200
# Epoch 13, CIFAR-10 Batch 5:  Loss:     0.9144 Validation Accuracy: 0.610400
# Epoch 14, CIFAR-10 Batch 1:  Loss:     0.9226 Validation Accuracy: 0.633200
# Epoch 14, CIFAR-10 Batch 2:  Loss:     0.8348 Validation Accuracy: 0.632000
# Epoch 14, CIFAR-10 Batch 3:  Loss:     0.7984 Validation Accuracy: 0.609600
# Epoch 14, CIFAR-10 Batch 4:  Loss:     0.9161 Validation Accuracy: 0.641800
# Epoch 14, CIFAR-10 Batch 5:  Loss:     0.9367 Validation Accuracy: 0.622200
# Epoch 15, CIFAR-10 Batch 1:  Loss:     0.8876 Validation Accuracy: 0.638400
# Epoch 15, CIFAR-10 Batch 2:  Loss:     0.8377 Validation Accuracy: 0.628400
# Epoch 15, CIFAR-10 Batch 3:  Loss:     0.7500 Validation Accuracy: 0.628800
# Epoch 15, CIFAR-10 Batch 4:  Loss:     0.8816 Validation Accuracy: 0.634200
# Epoch 15, CIFAR-10 Batch 5:  Loss:     0.8954 Validation Accuracy: 0.634800
# Epoch 16, CIFAR-10 Batch 1:  Loss:     0.8857 Validation Accuracy: 0.635800
# Epoch 16, CIFAR-10 Batch 2:  Loss:     0.7432 Validation Accuracy: 0.637000
# Epoch 16, CIFAR-10 Batch 3:  Loss:     0.7927 Validation Accuracy: 0.625400
# Epoch 16, CIFAR-10 Batch 4:  Loss:     0.8956 Validation Accuracy: 0.636000
# Epoch 16, CIFAR-10 Batch 5:  Loss:     0.8892 Validation Accuracy: 0.636800
# Epoch 17, CIFAR-10 Batch 1:  Loss:     0.8598 Validation Accuracy: 0.643400
# Epoch 17, CIFAR-10 Batch 2:  Loss:     0.7398 Validation Accuracy: 0.641400
# Epoch 17, CIFAR-10 Batch 3:  Loss:     0.7524 Validation Accuracy: 0.623600
# Epoch 17, CIFAR-10 Batch 4:  Loss:     0.9086 Validation Accuracy: 0.645000
# Epoch 17, CIFAR-10 Batch 5:  Loss:     0.8396 Validation Accuracy: 0.642600
# Epoch 18, CIFAR-10 Batch 1:  Loss:     0.8288 Validation Accuracy: 0.649800
# Epoch 18, CIFAR-10 Batch 2:  Loss:     0.7405 Validation Accuracy: 0.645600
# Epoch 18, CIFAR-10 Batch 3:  Loss:     0.6973 Validation Accuracy: 0.640800
# Epoch 18, CIFAR-10 Batch 4:  Loss:     0.7730 Validation Accuracy: 0.643200
# Epoch 18, CIFAR-10 Batch 5:  Loss:     0.8708 Validation Accuracy: 0.638000
# Epoch 19, CIFAR-10 Batch 1:  Loss:     0.7783 Validation Accuracy: 0.631000
# Epoch 19, CIFAR-10 Batch 2:  Loss:     0.7097 Validation Accuracy: 0.639200
# Epoch 19, CIFAR-10 Batch 3:  Loss:     0.6917 Validation Accuracy: 0.638200
# Epoch 19, CIFAR-10 Batch 4:  Loss:     0.7904 Validation Accuracy: 0.644200
# Epoch 19, CIFAR-10 Batch 5:  Loss:     0.7935 Validation Accuracy: 0.649600
# Epoch 20, CIFAR-10 Batch 1:  Loss:     0.8088 Validation Accuracy: 0.641200
# Epoch 20, CIFAR-10 Batch 2:  Loss:     0.6987 Validation Accuracy: 0.634800
# Epoch 20, CIFAR-10 Batch 3:  Loss:     0.6732 Validation Accuracy: 0.636400
# Epoch 20, CIFAR-10 Batch 4:  Loss:     0.7297 Validation Accuracy: 0.656200
# Epoch 20, CIFAR-10 Batch 5:  Loss:     0.7807 Validation Accuracy: 0.643400
# Epoch 21, CIFAR-10 Batch 1:  Loss:     0.7252 Validation Accuracy: 0.655000
# Epoch 21, CIFAR-10 Batch 2:  Loss:     0.6677 Validation Accuracy: 0.654200
# Epoch 21, CIFAR-10 Batch 3:  Loss:     0.6391 Validation Accuracy: 0.646000
# Epoch 21, CIFAR-10 Batch 4:  Loss:     0.7206 Validation Accuracy: 0.660000
# Epoch 21, CIFAR-10 Batch 5:  Loss:     0.8467 Validation Accuracy: 0.650800
# Epoch 22, CIFAR-10 Batch 1:  Loss:     0.7315 Validation Accuracy: 0.636600
# Epoch 22, CIFAR-10 Batch 2:  Loss:     0.7116 Validation Accuracy: 0.646800
# Epoch 22, CIFAR-10 Batch 3:  Loss:     0.6134 Validation Accuracy: 0.653200
# Epoch 22, CIFAR-10 Batch 4:  Loss:     0.7659 Validation Accuracy: 0.662800
# Epoch 22, CIFAR-10 Batch 5:  Loss:     0.8271 Validation Accuracy: 0.655400
# Epoch 23, CIFAR-10 Batch 1:  Loss:     0.7815 Validation Accuracy: 0.646200
# Epoch 23, CIFAR-10 Batch 2:  Loss:     0.6405 Validation Accuracy: 0.663200
# Epoch 23, CIFAR-10 Batch 3:  Loss:     0.6378 Validation Accuracy: 0.651600
# Epoch 23, CIFAR-10 Batch 4:  Loss:     0.7341 Validation Accuracy: 0.663000
# Epoch 23, CIFAR-10 Batch 5:  Loss:     0.7582 Validation Accuracy: 0.664200
# Epoch 24, CIFAR-10 Batch 1:  Loss:     0.7401 Validation Accuracy: 0.662000
# Epoch 24, CIFAR-10 Batch 2:  Loss:     0.6690 Validation Accuracy: 0.659600
# Epoch 24, CIFAR-10 Batch 3:  Loss:     0.5956 Validation Accuracy: 0.654400
# Epoch 24, CIFAR-10 Batch 4:  Loss:     0.6938 Validation Accuracy: 0.661400
# Epoch 24, CIFAR-10 Batch 5:  Loss:     0.7551 Validation Accuracy: 0.653800
# Epoch 25, CIFAR-10 Batch 1:  Loss:     0.7634 Validation Accuracy: 0.667800
# Epoch 25, CIFAR-10 Batch 2:  Loss:     0.6115 Validation Accuracy: 0.657800
# Epoch 25, CIFAR-10 Batch 3:  Loss:     0.6171 Validation Accuracy: 0.641200
# Epoch 25, CIFAR-10 Batch 4:  Loss:     0.6859 Validation Accuracy: 0.668200
# Epoch 25, CIFAR-10 Batch 5:  Loss:     0.7327 Validation Accuracy: 0.661200
# Epoch 26, CIFAR-10 Batch 1:  Loss:     0.6699 Validation Accuracy: 0.655800
# Epoch 26, CIFAR-10 Batch 2:  Loss:     0.5874 Validation Accuracy: 0.659000
# Epoch 26, CIFAR-10 Batch 3:  Loss:     0.5805 Validation Accuracy: 0.644400
# Epoch 26, CIFAR-10 Batch 4:  Loss:     0.6453 Validation Accuracy: 0.665600
# Epoch 26, CIFAR-10 Batch 5:  Loss:     0.7267 Validation Accuracy: 0.669200
# Epoch 27, CIFAR-10 Batch 1:  Loss:     0.6920 Validation Accuracy: 0.665600
# Epoch 27, CIFAR-10 Batch 2:  Loss:     0.6303 Validation Accuracy: 0.665200
# Epoch 27, CIFAR-10 Batch 3:  Loss:     0.5710 Validation Accuracy: 0.648600
# Epoch 27, CIFAR-10 Batch 4:  Loss:     0.6464 Validation Accuracy: 0.668000
# Epoch 27, CIFAR-10 Batch 5:  Loss:     0.7168 Validation Accuracy: 0.656800
# Epoch 28, CIFAR-10 Batch 1:  Loss:     0.6992 Validation Accuracy: 0.666200
# Epoch 28, CIFAR-10 Batch 2:  Loss:     0.5409 Validation Accuracy: 0.666200
# Epoch 28, CIFAR-10 Batch 3:  Loss:     0.5643 Validation Accuracy: 0.667800
# Epoch 28, CIFAR-10 Batch 4:  Loss:     0.6257 Validation Accuracy: 0.675600
# Epoch 28, CIFAR-10 Batch 5:  Loss:     0.7526 Validation Accuracy: 0.660600
# Epoch 29, CIFAR-10 Batch 1:  Loss:     0.6878 Validation Accuracy: 0.672200
# Epoch 29, CIFAR-10 Batch 2:  Loss:     0.5892 Validation Accuracy: 0.662800
# Epoch 29, CIFAR-10 Batch 3:  Loss:     0.5271 Validation Accuracy: 0.666200
# Epoch 29, CIFAR-10 Batch 4:  Loss:     0.6153 Validation Accuracy: 0.679400
# Epoch 29, CIFAR-10 Batch 5:  Loss:     0.7246 Validation Accuracy: 0.658600
# Epoch 30, CIFAR-10 Batch 1:  Loss:     0.6323 Validation Accuracy: 0.651800
# Epoch 30, CIFAR-10 Batch 2:  Loss:     0.5692 Validation Accuracy: 0.674200
# Epoch 30, CIFAR-10 Batch 3:  Loss:     0.5223 Validation Accuracy: 0.654400
# Epoch 30, CIFAR-10 Batch 4:  Loss:     0.5841 Validation Accuracy: 0.677600
# Epoch 30, CIFAR-10 Batch 5:  Loss:     0.6829 Validation Accuracy: 0.668400
# Epoch 31, CIFAR-10 Batch 1:  Loss:     0.5978 Validation Accuracy: 0.651400
# Epoch 31, CIFAR-10 Batch 2:  Loss:     0.5107 Validation Accuracy: 0.660600
# Epoch 31, CIFAR-10 Batch 3:  Loss:     0.5383 Validation Accuracy: 0.664400
# Epoch 31, CIFAR-10 Batch 4:  Loss:     0.5262 Validation Accuracy: 0.674200
# Epoch 31, CIFAR-10 Batch 5:  Loss:     0.6823 Validation Accuracy: 0.663400
# Epoch 32, CIFAR-10 Batch 1:  Loss:     0.6785 Validation Accuracy: 0.642000
# Epoch 32, CIFAR-10 Batch 2:  Loss:     0.5358 Validation Accuracy: 0.682000
# Epoch 32, CIFAR-10 Batch 3:  Loss:     0.5186 Validation Accuracy: 0.665000
# Epoch 32, CIFAR-10 Batch 4:  Loss:     0.6064 Validation Accuracy: 0.673800
# Epoch 32, CIFAR-10 Batch 5:  Loss:     0.6838 Validation Accuracy: 0.666200
# Epoch 33, CIFAR-10 Batch 1:  Loss:     0.6061 Validation Accuracy: 0.670800
# Epoch 33, CIFAR-10 Batch 2:  Loss:     0.5030 Validation Accuracy: 0.674400
# Epoch 33, CIFAR-10 Batch 3:  Loss:     0.5278 Validation Accuracy: 0.675000
# Epoch 33, CIFAR-10 Batch 4:  Loss:     0.5747 Validation Accuracy: 0.677600
# Epoch 33, CIFAR-10 Batch 5:  Loss:     0.6429 Validation Accuracy: 0.673200
# Epoch 34, CIFAR-10 Batch 1:  Loss:     0.6122 Validation Accuracy: 0.661800
# Epoch 34, CIFAR-10 Batch 2:  Loss:     0.5356 Validation Accuracy: 0.669200
# Epoch 34, CIFAR-10 Batch 3:  Loss:     0.5113 Validation Accuracy: 0.664400
# Epoch 34, CIFAR-10 Batch 4:  Loss:     0.5379 Validation Accuracy: 0.670000
# Epoch 34, CIFAR-10 Batch 5:  Loss:     0.6136 Validation Accuracy: 0.675600
# Epoch 35, CIFAR-10 Batch 1:  Loss:     0.5601 Validation Accuracy: 0.678200
# Epoch 35, CIFAR-10 Batch 2:  Loss:     0.5344 Validation Accuracy: 0.681600
# Epoch 35, CIFAR-10 Batch 3:  Loss:     0.4716 Validation Accuracy: 0.676600
# Epoch 35, CIFAR-10 Batch 4:  Loss:     0.5461 Validation Accuracy: 0.676000
# Epoch 35, CIFAR-10 Batch 5:  Loss:     0.5962 Validation Accuracy: 0.671200
# Epoch 36, CIFAR-10 Batch 1:  Loss:     0.5991 Validation Accuracy: 0.668200
# Epoch 36, CIFAR-10 Batch 2:  Loss:     0.4882 Validation Accuracy: 0.679000
# Epoch 36, CIFAR-10 Batch 3:  Loss:     0.4879 Validation Accuracy: 0.673600
# Epoch 36, CIFAR-10 Batch 4:  Loss:     0.5194 Validation Accuracy: 0.686600
# Epoch 36, CIFAR-10 Batch 5:  Loss:     0.6186 Validation Accuracy: 0.678800
# Epoch 37, CIFAR-10 Batch 1:  Loss:     0.5565 Validation Accuracy: 0.675400
# Epoch 37, CIFAR-10 Batch 2:  Loss:     0.5320 Validation Accuracy: 0.671800
# Epoch 37, CIFAR-10 Batch 3:  Loss:     0.4835 Validation Accuracy: 0.670800
# Epoch 37, CIFAR-10 Batch 4:  Loss:     0.4963 Validation Accuracy: 0.682000
# Epoch 37, CIFAR-10 Batch 5:  Loss:     0.7015 Validation Accuracy: 0.661000
# Epoch 38, CIFAR-10 Batch 1:  Loss:     0.5870 Validation Accuracy: 0.676200
# Epoch 38, CIFAR-10 Batch 2:  Loss:     0.4902 Validation Accuracy: 0.678200
# Epoch 38, CIFAR-10 Batch 3:  Loss:     0.4800 Validation Accuracy: 0.672200
# Epoch 38, CIFAR-10 Batch 4:  Loss:     0.4944 Validation Accuracy: 0.689400
# Epoch 38, CIFAR-10 Batch 5:  Loss:     0.6056 Validation Accuracy: 0.671800
# Epoch 39, CIFAR-10 Batch 1:  Loss:     0.5248 Validation Accuracy: 0.671200
# Epoch 39, CIFAR-10 Batch 2:  Loss:     0.4813 Validation Accuracy: 0.682200
# Epoch 39, CIFAR-10 Batch 3:  Loss:     0.4810 Validation Accuracy: 0.680800
# Epoch 39, CIFAR-10 Batch 4:  Loss:     0.4959 Validation Accuracy: 0.681800
# Epoch 39, CIFAR-10 Batch 5:  Loss:     0.5653 Validation Accuracy: 0.675600
# Epoch 40, CIFAR-10 Batch 1:  Loss:     0.5361 Validation Accuracy: 0.681600
# Epoch 40, CIFAR-10 Batch 2:  Loss:     0.4986 Validation Accuracy: 0.677600
# Epoch 40, CIFAR-10 Batch 3:  Loss:     0.4492 Validation Accuracy: 0.670000
# Epoch 40, CIFAR-10 Batch 4:  Loss:     0.5231 Validation Accuracy: 0.683600
# Epoch 40, CIFAR-10 Batch 5:  Loss:     0.6025 Validation Accuracy: 0.670600
# Epoch 41, CIFAR-10 Batch 1:  Loss:     0.4807 Validation Accuracy: 0.659400
# Epoch 41, CIFAR-10 Batch 2:  Loss:     0.4610 Validation Accuracy: 0.679800
# Epoch 41, CIFAR-10 Batch 3:  Loss:     0.4448 Validation Accuracy: 0.680000
# Epoch 41, CIFAR-10 Batch 4:  Loss:     0.5159 Validation Accuracy: 0.682600
# Epoch 41, CIFAR-10 Batch 5:  Loss:     0.6285 Validation Accuracy: 0.675800
# Epoch 42, CIFAR-10 Batch 1:  Loss:     0.5308 Validation Accuracy: 0.680200
# Epoch 42, CIFAR-10 Batch 2:  Loss:     0.4753 Validation Accuracy: 0.686800
# Epoch 42, CIFAR-10 Batch 3:  Loss:     0.4309 Validation Accuracy: 0.677200
# Epoch 42, CIFAR-10 Batch 4:  Loss:     0.4690 Validation Accuracy: 0.686600
# Epoch 42, CIFAR-10 Batch 5:  Loss:     0.5801 Validation Accuracy: 0.676800
# Epoch 43, CIFAR-10 Batch 1:  Loss:     0.5278 Validation Accuracy: 0.668800
# Epoch 43, CIFAR-10 Batch 2:  Loss:     0.4514 Validation Accuracy: 0.687200
# Epoch 43, CIFAR-10 Batch 3:  Loss:     0.4316 Validation Accuracy: 0.677600
# Epoch 43, CIFAR-10 Batch 4:  Loss:     0.4384 Validation Accuracy: 0.690000
# Epoch 43, CIFAR-10 Batch 5:  Loss:     0.5420 Validation Accuracy: 0.678400
# Epoch 44, CIFAR-10 Batch 1:  Loss:     0.5278 Validation Accuracy: 0.688400
# Epoch 44, CIFAR-10 Batch 2:  Loss:     0.4360 Validation Accuracy: 0.689800
# Epoch 44, CIFAR-10 Batch 3:  Loss:     0.4038 Validation Accuracy: 0.672000
# Epoch 44, CIFAR-10 Batch 4:  Loss:     0.4842 Validation Accuracy: 0.686600
# Epoch 44, CIFAR-10 Batch 5:  Loss:     0.5522 Validation Accuracy: 0.673400
# Epoch 45, CIFAR-10 Batch 1:  Loss:     0.5109 Validation Accuracy: 0.684000
# Epoch 45, CIFAR-10 Batch 2:  Loss:     0.4818 Validation Accuracy: 0.688600
# Epoch 45, CIFAR-10 Batch 3:  Loss:     0.4141 Validation Accuracy: 0.671600
# Epoch 45, CIFAR-10 Batch 4:  Loss:     0.4385 Validation Accuracy: 0.690000
# Epoch 45, CIFAR-10 Batch 5:  Loss:     0.5474 Validation Accuracy: 0.677600
# Epoch 46, CIFAR-10 Batch 1:  Loss:     0.4814 Validation Accuracy: 0.666400
# Epoch 46, CIFAR-10 Batch 2:  Loss:     0.4334 Validation Accuracy: 0.673400
# Epoch 46, CIFAR-10 Batch 3:  Loss:     0.4207 Validation Accuracy: 0.687000
# Epoch 46, CIFAR-10 Batch 4:  Loss:     0.4454 Validation Accuracy: 0.686600
# Epoch 46, CIFAR-10 Batch 5:  Loss:     0.5111 Validation Accuracy: 0.682000
# Epoch 47, CIFAR-10 Batch 1:  Loss:     0.5273 Validation Accuracy: 0.679600
# Epoch 47, CIFAR-10 Batch 2:  Loss:     0.4315 Validation Accuracy: 0.691800
# Epoch 47, CIFAR-10 Batch 3:  Loss:     0.4064 Validation Accuracy: 0.673200
# Epoch 47, CIFAR-10 Batch 4:  Loss:     0.4246 Validation Accuracy: 0.685800
# Epoch 47, CIFAR-10 Batch 5:  Loss:     0.5022 Validation Accuracy: 0.681400
# Epoch 48, CIFAR-10 Batch 1:  Loss:     0.4874 Validation Accuracy: 0.676400
# Epoch 48, CIFAR-10 Batch 2:  Loss:     0.4467 Validation Accuracy: 0.690200
# Epoch 48, CIFAR-10 Batch 3:  Loss:     0.4148 Validation Accuracy: 0.676800
# Epoch 48, CIFAR-10 Batch 4:  Loss:     0.4474 Validation Accuracy: 0.683000
# Epoch 48, CIFAR-10 Batch 5:  Loss:     0.5221 Validation Accuracy: 0.680400
# Epoch 49, CIFAR-10 Batch 1:  Loss:     0.5008 Validation Accuracy: 0.688400
# Epoch 49, CIFAR-10 Batch 2:  Loss:     0.4378 Validation Accuracy: 0.691400
# Epoch 49, CIFAR-10 Batch 3:  Loss:     0.4208 Validation Accuracy: 0.685400
# Epoch 49, CIFAR-10 Batch 4:  Loss:     0.4316 Validation Accuracy: 0.689800
# Epoch 49, CIFAR-10 Batch 5:  Loss:     0.5235 Validation Accuracy: 0.668200
# Epoch 50, CIFAR-10 Batch 1:  Loss:     0.4399 Validation Accuracy: 0.668800
# Epoch 50, CIFAR-10 Batch 2:  Loss:     0.3873 Validation Accuracy: 0.682800
# Epoch 50, CIFAR-10 Batch 3:  Loss:     0.3892 Validation Accuracy: 0.672200
# Epoch 50, CIFAR-10 Batch 4:  Loss:     0.4290 Validation Accuracy: 0.691000
# Epoch 50, CIFAR-10 Batch 5:  Loss:     0.5110 Validation Accuracy: 0.682600
# Epoch 51, CIFAR-10 Batch 1:  Loss:     0.4662 Validation Accuracy: 0.687600
# Epoch 51, CIFAR-10 Batch 2:  Loss:     0.3996 Validation Accuracy: 0.680200
# Epoch 51, CIFAR-10 Batch 3:  Loss:     0.3733 Validation Accuracy: 0.670000
# Epoch 51, CIFAR-10 Batch 4:  Loss:     0.4228 Validation Accuracy: 0.681400
# Epoch 51, CIFAR-10 Batch 5:  Loss:     0.5042 Validation Accuracy: 0.677400
# Epoch 52, CIFAR-10 Batch 1:  Loss:     0.4501 Validation Accuracy: 0.692000
# Epoch 52, CIFAR-10 Batch 2:  Loss:     0.3715 Validation Accuracy: 0.694400
# Epoch 52, CIFAR-10 Batch 3:  Loss:     0.4004 Validation Accuracy: 0.694200
# Epoch 52, CIFAR-10 Batch 4:  Loss:     0.3943 Validation Accuracy: 0.700200
# Epoch 52, CIFAR-10 Batch 5:  Loss:     0.5166 Validation Accuracy: 0.680200
# Epoch 53, CIFAR-10 Batch 1:  Loss:     0.4321 Validation Accuracy: 0.691800
# Epoch 53, CIFAR-10 Batch 2:  Loss:     0.3542 Validation Accuracy: 0.701600
# Epoch 53, CIFAR-10 Batch 3:  Loss:     0.3682 Validation Accuracy: 0.671600
# Epoch 53, CIFAR-10 Batch 4:  Loss:     0.4094 Validation Accuracy: 0.695000
# Epoch 53, CIFAR-10 Batch 5:  Loss:     0.5146 Validation Accuracy: 0.686400
# Epoch 54, CIFAR-10 Batch 1:  Loss:     0.4351 Validation Accuracy: 0.686200
# Epoch 54, CIFAR-10 Batch 2:  Loss:     0.3747 Validation Accuracy: 0.686800
# Epoch 54, CIFAR-10 Batch 3:  Loss:     0.3270 Validation Accuracy: 0.688200
# Epoch 54, CIFAR-10 Batch 4:  Loss:     0.3616 Validation Accuracy: 0.686800
# Epoch 54, CIFAR-10 Batch 5:  Loss:     0.5608 Validation Accuracy: 0.675000
# Epoch 55, CIFAR-10 Batch 1:  Loss:     0.4438 Validation Accuracy: 0.680200
# Epoch 55, CIFAR-10 Batch 2:  Loss:     0.3440 Validation Accuracy: 0.686600
# Epoch 55, CIFAR-10 Batch 3:  Loss:     0.3109 Validation Accuracy: 0.687000
# Epoch 55, CIFAR-10 Batch 4:  Loss:     0.4102 Validation Accuracy: 0.686800
# Epoch 55, CIFAR-10 Batch 5:  Loss:     0.4587 Validation Accuracy: 0.685800
# Epoch 56, CIFAR-10 Batch 1:  Loss:     0.3866 Validation Accuracy: 0.689200
# Epoch 56, CIFAR-10 Batch 2:  Loss:     0.3898 Validation Accuracy: 0.689000
# Epoch 56, CIFAR-10 Batch 3:  Loss:     0.3459 Validation Accuracy: 0.697800
# Epoch 56, CIFAR-10 Batch 4:  Loss:     0.4079 Validation Accuracy: 0.699200
# Epoch 56, CIFAR-10 Batch 5:  Loss:     0.5000 Validation Accuracy: 0.690000
# Epoch 57, CIFAR-10 Batch 1:  Loss:     0.3838 Validation Accuracy: 0.692800
# Epoch 57, CIFAR-10 Batch 2:  Loss:     0.3727 Validation Accuracy: 0.687800
# Epoch 57, CIFAR-10 Batch 3:  Loss:     0.3656 Validation Accuracy: 0.681800
# Epoch 57, CIFAR-10 Batch 4:  Loss:     0.3822 Validation Accuracy: 0.693800
# Epoch 57, CIFAR-10 Batch 5:  Loss:     0.5122 Validation Accuracy: 0.678400
# Epoch 58, CIFAR-10 Batch 1:  Loss:     0.4135 Validation Accuracy: 0.694000
# Epoch 58, CIFAR-10 Batch 2:  Loss:     0.4412 Validation Accuracy: 0.684800
# Epoch 58, CIFAR-10 Batch 3:  Loss:     0.3497 Validation Accuracy: 0.686200
# Epoch 58, CIFAR-10 Batch 4:  Loss:     0.3848 Validation Accuracy: 0.695000
# Epoch 58, CIFAR-10 Batch 5:  Loss:     0.4678 Validation Accuracy: 0.680400
# Epoch 59, CIFAR-10 Batch 1:  Loss:     0.4091 Validation Accuracy: 0.684000
# Epoch 59, CIFAR-10 Batch 2:  Loss:     0.3501 Validation Accuracy: 0.687600
# Epoch 59, CIFAR-10 Batch 3:  Loss:     0.3616 Validation Accuracy: 0.682000
# Epoch 59, CIFAR-10 Batch 4:  Loss:     0.4191 Validation Accuracy: 0.686800
# Epoch 59, CIFAR-10 Batch 5:  Loss:     0.4647 Validation Accuracy: 0.677600
# Epoch 60, CIFAR-10 Batch 1:  Loss:     0.4585 Validation Accuracy: 0.687800
# Epoch 60, CIFAR-10 Batch 2:  Loss:     0.3513 Validation Accuracy: 0.686200
# Epoch 60, CIFAR-10 Batch 3:  Loss:     0.3250 Validation Accuracy: 0.684800
# Epoch 60, CIFAR-10 Batch 4:  Loss:     0.3679 Validation Accuracy: 0.695000
# Epoch 60, CIFAR-10 Batch 5:  Loss:     0.4441 Validation Accuracy: 0.693600
# Epoch 61, CIFAR-10 Batch 1:  Loss:     0.4136 Validation Accuracy: 0.694600
# Epoch 61, CIFAR-10 Batch 2:  Loss:     0.3860 Validation Accuracy: 0.693600
# Epoch 61, CIFAR-10 Batch 3:  Loss:     0.3869 Validation Accuracy: 0.691200
# Epoch 61, CIFAR-10 Batch 4:  Loss:     0.3672 Validation Accuracy: 0.697200
# Epoch 61, CIFAR-10 Batch 5:  Loss:     0.4489 Validation Accuracy: 0.685800
# Epoch 62, CIFAR-10 Batch 1:  Loss:     0.4115 Validation Accuracy: 0.687800
# Epoch 62, CIFAR-10 Batch 2:  Loss:     0.3387 Validation Accuracy: 0.686800
# Epoch 62, CIFAR-10 Batch 3:  Loss:     0.3138 Validation Accuracy: 0.683600
# Epoch 62, CIFAR-10 Batch 4:  Loss:     0.3771 Validation Accuracy: 0.679600
# Epoch 62, CIFAR-10 Batch 5:  Loss:     0.4517 Validation Accuracy: 0.689000
# Epoch 63, CIFAR-10 Batch 1:  Loss:     0.3475 Validation Accuracy: 0.676000
# Epoch 63, CIFAR-10 Batch 2:  Loss:     0.3195 Validation Accuracy: 0.679000
# Epoch 63, CIFAR-10 Batch 3:  Loss:     0.3432 Validation Accuracy: 0.681000
# Epoch 63, CIFAR-10 Batch 4:  Loss:     0.3581 Validation Accuracy: 0.696200
# Epoch 63, CIFAR-10 Batch 5:  Loss:     0.4506 Validation Accuracy: 0.685000
# Epoch 64, CIFAR-10 Batch 1:  Loss:     0.3662 Validation Accuracy: 0.693600
# Epoch 64, CIFAR-10 Batch 2:  Loss:     0.3221 Validation Accuracy: 0.687800
# Epoch 64, CIFAR-10 Batch 3:  Loss:     0.3597 Validation Accuracy: 0.679400
# Epoch 64, CIFAR-10 Batch 4:  Loss:     0.4140 Validation Accuracy: 0.687000
# Epoch 64, CIFAR-10 Batch 5:  Loss:     0.4091 Validation Accuracy: 0.689800
# Epoch 65, CIFAR-10 Batch 1:  Loss:     0.3567 Validation Accuracy: 0.687400
# Epoch 65, CIFAR-10 Batch 2:  Loss:     0.3548 Validation Accuracy: 0.694800
# Epoch 65, CIFAR-10 Batch 3:  Loss:     0.3041 Validation Accuracy: 0.696000
# Epoch 65, CIFAR-10 Batch 4:  Loss:     0.3590 Validation Accuracy: 0.693600
# Epoch 65, CIFAR-10 Batch 5:  Loss:     0.3840 Validation Accuracy: 0.683800
# Epoch 66, CIFAR-10 Batch 1:  Loss:     0.3851 Validation Accuracy: 0.687400
# Epoch 66, CIFAR-10 Batch 2:  Loss:     0.3053 Validation Accuracy: 0.694000
# Epoch 66, CIFAR-10 Batch 3:  Loss:     0.3200 Validation Accuracy: 0.678800
# Epoch 66, CIFAR-10 Batch 4:  Loss:     0.3731 Validation Accuracy: 0.698400
# Epoch 66, CIFAR-10 Batch 5:  Loss:     0.4563 Validation Accuracy: 0.672600
# Epoch 67, CIFAR-10 Batch 1:  Loss:     0.3808 Validation Accuracy: 0.696000
# Epoch 67, CIFAR-10 Batch 2:  Loss:     0.3338 Validation Accuracy: 0.697800
# Epoch 67, CIFAR-10 Batch 3:  Loss:     0.3045 Validation Accuracy: 0.685400
# Epoch 67, CIFAR-10 Batch 4:  Loss:     0.3691 Validation Accuracy: 0.697800
# Epoch 67, CIFAR-10 Batch 5:  Loss:     0.3969 Validation Accuracy: 0.693600
# Epoch 68, CIFAR-10 Batch 1:  Loss:     0.3763 Validation Accuracy: 0.693000
# Epoch 68, CIFAR-10 Batch 2:  Loss:     0.4317 Validation Accuracy: 0.692800
# Epoch 68, CIFAR-10 Batch 3:  Loss:     0.2989 Validation Accuracy: 0.691000
# Epoch 68, CIFAR-10 Batch 4:  Loss:     0.3406 Validation Accuracy: 0.694600
# Epoch 68, CIFAR-10 Batch 5:  Loss:     0.4110 Validation Accuracy: 0.691600
# Epoch 69, CIFAR-10 Batch 1:  Loss:     0.3546 Validation Accuracy: 0.696400
# Epoch 69, CIFAR-10 Batch 2:  Loss:     0.3348 Validation Accuracy: 0.698000
# Epoch 69, CIFAR-10 Batch 3:  Loss:     0.2856 Validation Accuracy: 0.693200
# Epoch 69, CIFAR-10 Batch 4:  Loss:     0.3732 Validation Accuracy: 0.682400
# Epoch 69, CIFAR-10 Batch 5:  Loss:     0.3892 Validation Accuracy: 0.687000
# Epoch 70, CIFAR-10 Batch 1:  Loss:     0.3728 Validation Accuracy: 0.698000
# Epoch 70, CIFAR-10 Batch 2:  Loss:     0.3629 Validation Accuracy: 0.693000
# Epoch 70, CIFAR-10 Batch 3:  Loss:     0.2931 Validation Accuracy: 0.689200
# Epoch 70, CIFAR-10 Batch 4:  Loss:     0.3606 Validation Accuracy: 0.689600
# Epoch 70, CIFAR-10 Batch 5:  Loss:     0.3794 Validation Accuracy: 0.685600
# Epoch 71, CIFAR-10 Batch 1:  Loss:     0.3240 Validation Accuracy: 0.694200
# Epoch 71, CIFAR-10 Batch 2:  Loss:     0.3634 Validation Accuracy: 0.684400
# Epoch 71, CIFAR-10 Batch 3:  Loss:     0.3155 Validation Accuracy: 0.684600
# Epoch 71, CIFAR-10 Batch 4:  Loss:     0.3305 Validation Accuracy: 0.692400
# Epoch 71, CIFAR-10 Batch 5:  Loss:     0.3984 Validation Accuracy: 0.672000
# Epoch 72, CIFAR-10 Batch 1:  Loss:     0.3560 Validation Accuracy: 0.690000
# Epoch 72, CIFAR-10 Batch 2:  Loss:     0.3502 Validation Accuracy: 0.694800
# Epoch 72, CIFAR-10 Batch 3:  Loss:     0.2979 Validation Accuracy: 0.679800
# Epoch 72, CIFAR-10 Batch 4:  Loss:     0.3350 Validation Accuracy: 0.696400
# Epoch 72, CIFAR-10 Batch 5:  Loss:     0.3318 Validation Accuracy: 0.693400
# Epoch 73, CIFAR-10 Batch 1:  Loss:     0.3255 Validation Accuracy: 0.698600
# Epoch 73, CIFAR-10 Batch 2:  Loss:     0.3557 Validation Accuracy: 0.695400
# Epoch 73, CIFAR-10 Batch 3:  Loss:     0.2954 Validation Accuracy: 0.698400
# Epoch 73, CIFAR-10 Batch 4:  Loss:     0.3897 Validation Accuracy: 0.696800
# Epoch 73, CIFAR-10 Batch 5:  Loss:     0.3510 Validation Accuracy: 0.692800
# Epoch 74, CIFAR-10 Batch 1:  Loss:     0.3722 Validation Accuracy: 0.696800
# Epoch 74, CIFAR-10 Batch 2:  Loss:     0.3646 Validation Accuracy: 0.687200
# Epoch 74, CIFAR-10 Batch 3:  Loss:     0.3091 Validation Accuracy: 0.682800
# Epoch 74, CIFAR-10 Batch 4:  Loss:     0.3484 Validation Accuracy: 0.695400
# Epoch 74, CIFAR-10 Batch 5:  Loss:     0.4016 Validation Accuracy: 0.691200
# Epoch 75, CIFAR-10 Batch 1:  Loss:     0.3730 Validation Accuracy: 0.666400
# Epoch 75, CIFAR-10 Batch 2:  Loss:     0.3203 Validation Accuracy: 0.697400
# Epoch 75, CIFAR-10 Batch 3:  Loss:     0.2987 Validation Accuracy: 0.696600
# Epoch 75, CIFAR-10 Batch 4:  Loss:     0.3429 Validation Accuracy: 0.691800
# Epoch 75, CIFAR-10 Batch 5:  Loss:     0.4181 Validation Accuracy: 0.689600
# Epoch 76, CIFAR-10 Batch 1:  Loss:     0.3079 Validation Accuracy: 0.697800
# Epoch 76, CIFAR-10 Batch 2:  Loss:     0.3190 Validation Accuracy: 0.688800
# Epoch 76, CIFAR-10 Batch 3:  Loss:     0.2928 Validation Accuracy: 0.697400
# Epoch 76, CIFAR-10 Batch 4:  Loss:     0.3345 Validation Accuracy: 0.697000
# Epoch 76, CIFAR-10 Batch 5:  Loss:     0.3797 Validation Accuracy: 0.694600
# Epoch 77, CIFAR-10 Batch 1:  Loss:     0.3447 Validation Accuracy: 0.697800
# Epoch 77, CIFAR-10 Batch 2:  Loss:     0.3227 Validation Accuracy: 0.689000
# Epoch 77, CIFAR-10 Batch 3:  Loss:     0.3139 Validation Accuracy: 0.688400
# Epoch 77, CIFAR-10 Batch 4:  Loss:     0.3524 Validation Accuracy: 0.697000
# Epoch 77, CIFAR-10 Batch 5:  Loss:     0.4094 Validation Accuracy: 0.688000
# Epoch 78, CIFAR-10 Batch 1:  Loss:     0.3289 Validation Accuracy: 0.697600
# Epoch 78, CIFAR-10 Batch 2:  Loss:     0.3137 Validation Accuracy: 0.691600
# Epoch 78, CIFAR-10 Batch 3:  Loss:     0.2693 Validation Accuracy: 0.694800
# Epoch 78, CIFAR-10 Batch 4:  Loss:     0.3446 Validation Accuracy: 0.696400
# Epoch 78, CIFAR-10 Batch 5:  Loss:     0.3674 Validation Accuracy: 0.695400
# Epoch 79, CIFAR-10 Batch 1:  Loss:     0.3046 Validation Accuracy: 0.695400
# Epoch 79, CIFAR-10 Batch 2:  Loss:     0.2859 Validation Accuracy: 0.687200
# Epoch 79, CIFAR-10 Batch 3:  Loss:     0.2707 Validation Accuracy: 0.698400
# Epoch 79, CIFAR-10 Batch 4:  Loss:     0.3042 Validation Accuracy: 0.699600
# Epoch 79, CIFAR-10 Batch 5:  Loss:     0.3679 Validation Accuracy: 0.692600
# Epoch 80, CIFAR-10 Batch 1:  Loss:     0.2945 Validation Accuracy: 0.698600
# Epoch 80, CIFAR-10 Batch 2:  Loss:     0.2730 Validation Accuracy: 0.691800
# Epoch 80, CIFAR-10 Batch 3:  Loss:     0.2835 Validation Accuracy: 0.691000
# Epoch 80, CIFAR-10 Batch 4:  Loss:     0.3161 Validation Accuracy: 0.698000
# Epoch 80, CIFAR-10 Batch 5:  Loss:     0.3593 Validation Accuracy: 0.687800
# Epoch 81, CIFAR-10 Batch 1:  Loss:     0.2960 Validation Accuracy: 0.699200
# Epoch 81, CIFAR-10 Batch 2:  Loss:     0.2953 Validation Accuracy: 0.695000
# Epoch 81, CIFAR-10 Batch 3:  Loss:     0.2730 Validation Accuracy: 0.679400
# Epoch 81, CIFAR-10 Batch 4:  Loss:     0.3474 Validation Accuracy: 0.699200
# Epoch 81, CIFAR-10 Batch 5:  Loss:     0.3260 Validation Accuracy: 0.691800
# Epoch 82, CIFAR-10 Batch 1:  Loss:     0.3339 Validation Accuracy: 0.695600
# Epoch 82, CIFAR-10 Batch 2:  Loss:     0.3077 Validation Accuracy: 0.693800
# Epoch 82, CIFAR-10 Batch 3:  Loss:     0.2413 Validation Accuracy: 0.696600
# Epoch 82, CIFAR-10 Batch 4:  Loss:     0.3206 Validation Accuracy: 0.698600
# Epoch 82, CIFAR-10 Batch 5:  Loss:     0.3837 Validation Accuracy: 0.691800
# Epoch 83, CIFAR-10 Batch 1:  Loss:     0.3357 Validation Accuracy: 0.705000
# Epoch 83, CIFAR-10 Batch 2:  Loss:     0.3164 Validation Accuracy: 0.695000
# Epoch 83, CIFAR-10 Batch 3:  Loss:     0.3129 Validation Accuracy: 0.700600
# Epoch 83, CIFAR-10 Batch 4:  Loss:     0.3182 Validation Accuracy: 0.702600
# Epoch 83, CIFAR-10 Batch 5:  Loss:     0.3143 Validation Accuracy: 0.686800
# Epoch 84, CIFAR-10 Batch 1:  Loss:     0.3635 Validation Accuracy: 0.701400
# Epoch 84, CIFAR-10 Batch 2:  Loss:     0.3103 Validation Accuracy: 0.695200
# Epoch 84, CIFAR-10 Batch 3:  Loss:     0.2962 Validation Accuracy: 0.692400
# Epoch 84, CIFAR-10 Batch 4:  Loss:     0.3129 Validation Accuracy: 0.699600
# Epoch 84, CIFAR-10 Batch 5:  Loss:     0.3373 Validation Accuracy: 0.698200
# Epoch 85, CIFAR-10 Batch 1:  Loss:     0.3202 Validation Accuracy: 0.697200
# Epoch 85, CIFAR-10 Batch 2:  Loss:     0.3028 Validation Accuracy: 0.694600
# Epoch 85, CIFAR-10 Batch 3:  Loss:     0.2773 Validation Accuracy: 0.685000
# Epoch 85, CIFAR-10 Batch 4:  Loss:     0.3078 Validation Accuracy: 0.683000
# Epoch 85, CIFAR-10 Batch 5:  Loss:     0.3088 Validation Accuracy: 0.697400
# Epoch 86, CIFAR-10 Batch 1:  Loss:     0.3030 Validation Accuracy: 0.701400
# Epoch 86, CIFAR-10 Batch 2:  Loss:     0.2566 Validation Accuracy: 0.695200
# Epoch 86, CIFAR-10 Batch 3:  Loss:     0.2835 Validation Accuracy: 0.698600
# Epoch 86, CIFAR-10 Batch 4:  Loss:     0.2855 Validation Accuracy: 0.696600
# Epoch 86, CIFAR-10 Batch 5:  Loss:     0.3666 Validation Accuracy: 0.693800
# Epoch 87, CIFAR-10 Batch 1:  Loss:     0.3181 Validation Accuracy: 0.696200
# Epoch 87, CIFAR-10 Batch 2:  Loss:     0.2524 Validation Accuracy: 0.695000
# Epoch 87, CIFAR-10 Batch 3:  Loss:     0.2882 Validation Accuracy: 0.695400
# Epoch 87, CIFAR-10 Batch 4:  Loss:     0.3234 Validation Accuracy: 0.705400
# Epoch 87, CIFAR-10 Batch 5:  Loss:     0.3039 Validation Accuracy: 0.697400
# Epoch 88, CIFAR-10 Batch 1:  Loss:     0.3117 Validation Accuracy: 0.703400
# Epoch 88, CIFAR-10 Batch 2:  Loss:     0.2846 Validation Accuracy: 0.696200
# Epoch 88, CIFAR-10 Batch 3:  Loss:     0.2895 Validation Accuracy: 0.697400
# Epoch 88, CIFAR-10 Batch 4:  Loss:     0.3151 Validation Accuracy: 0.703600
# Epoch 88, CIFAR-10 Batch 5:  Loss:     0.2688 Validation Accuracy: 0.698600
# Epoch 89, CIFAR-10 Batch 1:  Loss:     0.2593 Validation Accuracy: 0.702200
# Epoch 89, CIFAR-10 Batch 2:  Loss:     0.3083 Validation Accuracy: 0.698000
# Epoch 89, CIFAR-10 Batch 3:  Loss:     0.2862 Validation Accuracy: 0.697400
# Epoch 89, CIFAR-10 Batch 4:  Loss:     0.3133 Validation Accuracy: 0.691400
# Epoch 89, CIFAR-10 Batch 5:  Loss:     0.3261 Validation Accuracy: 0.703200
# Epoch 90, CIFAR-10 Batch 1:  Loss:     0.2729 Validation Accuracy: 0.697600
# Epoch 90, CIFAR-10 Batch 2:  Loss:     0.3197 Validation Accuracy: 0.699600
# Epoch 90, CIFAR-10 Batch 3:  Loss:     0.2635 Validation Accuracy: 0.687600
# Epoch 90, CIFAR-10 Batch 4:  Loss:     0.2918 Validation Accuracy: 0.695600
# Epoch 90, CIFAR-10 Batch 5:  Loss:     0.2918 Validation Accuracy: 0.698800
# Epoch 91, CIFAR-10 Batch 1:  Loss:     0.2482 Validation Accuracy: 0.706400
# Epoch 91, CIFAR-10 Batch 2:  Loss:     0.2686 Validation Accuracy: 0.700800
# Epoch 91, CIFAR-10 Batch 3:  Loss:     0.2765 Validation Accuracy: 0.684600
# Epoch 91, CIFAR-10 Batch 4:  Loss:     0.3068 Validation Accuracy: 0.696600
# Epoch 91, CIFAR-10 Batch 5:  Loss:     0.2879 Validation Accuracy: 0.683400
# Epoch 92, CIFAR-10 Batch 1:  Loss:     0.2527 Validation Accuracy: 0.703800
# Epoch 92, CIFAR-10 Batch 2:  Loss:     0.2873 Validation Accuracy: 0.703000
# Epoch 92, CIFAR-10 Batch 3:  Loss:     0.2627 Validation Accuracy: 0.704000
# Epoch 92, CIFAR-10 Batch 4:  Loss:     0.2847 Validation Accuracy: 0.700400
# Epoch 92, CIFAR-10 Batch 5:  Loss:     0.2815 Validation Accuracy: 0.690600
# Epoch 93, CIFAR-10 Batch 1:  Loss:     0.2988 Validation Accuracy: 0.699800
# Epoch 93, CIFAR-10 Batch 2:  Loss:     0.3466 Validation Accuracy: 0.701000
# Epoch 93, CIFAR-10 Batch 3:  Loss:     0.3168 Validation Accuracy: 0.693000
# Epoch 93, CIFAR-10 Batch 4:  Loss:     0.3131 Validation Accuracy: 0.701000
# Epoch 93, CIFAR-10 Batch 5:  Loss:     0.2926 Validation Accuracy: 0.689000
# Epoch 94, CIFAR-10 Batch 1:  Loss:     0.2884 Validation Accuracy: 0.703600
# Epoch 94, CIFAR-10 Batch 2:  Loss:     0.2798 Validation Accuracy: 0.700200
# Epoch 94, CIFAR-10 Batch 3:  Loss:     0.2296 Validation Accuracy: 0.684600
# Epoch 94, CIFAR-10 Batch 4:  Loss:     0.2767 Validation Accuracy: 0.699400
# Epoch 94, CIFAR-10 Batch 5:  Loss:     0.2906 Validation Accuracy: 0.688400
# Epoch 95, CIFAR-10 Batch 1:  Loss:     0.2824 Validation Accuracy: 0.699600
# Epoch 95, CIFAR-10 Batch 2:  Loss:     0.3116 Validation Accuracy: 0.702800
# Epoch 95, CIFAR-10 Batch 3:  Loss:     0.2380 Validation Accuracy: 0.693200
# Epoch 95, CIFAR-10 Batch 4:  Loss:     0.2872 Validation Accuracy: 0.706200
# Epoch 95, CIFAR-10 Batch 5:  Loss:     0.2673 Validation Accuracy: 0.706400
# Epoch 96, CIFAR-10 Batch 1:  Loss:     0.2533 Validation Accuracy: 0.695600
# Epoch 96, CIFAR-10 Batch 2:  Loss:     0.2771 Validation Accuracy: 0.696800
# Epoch 96, CIFAR-10 Batch 3:  Loss:     0.3061 Validation Accuracy: 0.685200
# Epoch 96, CIFAR-10 Batch 4:  Loss:     0.2640 Validation Accuracy: 0.701200
# Epoch 96, CIFAR-10 Batch 5:  Loss:     0.2661 Validation Accuracy: 0.690200
# Epoch 97, CIFAR-10 Batch 1:  Loss:     0.2441 Validation Accuracy: 0.709200
# Epoch 97, CIFAR-10 Batch 2:  Loss:     0.2571 Validation Accuracy: 0.700600
# Epoch 97, CIFAR-10 Batch 3:  Loss:     0.2586 Validation Accuracy: 0.694400
# Epoch 97, CIFAR-10 Batch 4:  Loss:     0.2727 Validation Accuracy: 0.706200
# Epoch 97, CIFAR-10 Batch 5:  Loss:     0.2339 Validation Accuracy: 0.700200
# Epoch 98, CIFAR-10 Batch 1:  Loss:     0.2928 Validation Accuracy: 0.698400
# Epoch 98, CIFAR-10 Batch 2:  Loss:     0.2666 Validation Accuracy: 0.697600
# Epoch 98, CIFAR-10 Batch 3:  Loss:     0.2550 Validation Accuracy: 0.699800
# Epoch 98, CIFAR-10 Batch 4:  Loss:     0.2961 Validation Accuracy: 0.702800
# Epoch 98, CIFAR-10 Batch 5:  Loss:     0.3228 Validation Accuracy: 0.700800
# Epoch 99, CIFAR-10 Batch 1:  Loss:     0.2627 Validation Accuracy: 0.704200
# Epoch 99, CIFAR-10 Batch 2:  Loss:     0.3151 Validation Accuracy: 0.703200
# Epoch 99, CIFAR-10 Batch 3:  Loss:     0.2811 Validation Accuracy: 0.686000
# Epoch 99, CIFAR-10 Batch 4:  Loss:     0.3197 Validation Accuracy: 0.698000
# Epoch 99, CIFAR-10 Batch 5:  Loss:     0.2710 Validation Accuracy: 0.701400
# Epoch 100, CIFAR-10 Batch 1:  Loss:     0.2555 Validation Accuracy: 0.699800
# Epoch 100, CIFAR-10 Batch 2:  Loss:     0.2687 Validation Accuracy: 0.699200
# Epoch 100, CIFAR-10 Batch 3:  Loss:     0.3005 Validation Accuracy: 0.690000
# Epoch 100, CIFAR-10 Batch 4:  Loss:     0.2777 Validation Accuracy: 0.704400
# Epoch 100, CIFAR-10 Batch 5:  Loss:     0.2542 Validation Accuracy: 0.701600
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# /home/carnd/anaconda3/envs/dl/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#
# /home/carnd/anaconda3/envs/dl/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#
# /home/carnd/anaconda3/envs/dl/lib/python3.5/contextlib.py in __exit__(self, type, value, traceback)
#      65             try:
# ---> 66                 next(self.gen)
#      67             except StopIteration:
#
# /home/carnd/anaconda3/envs/dl/lib/python3.5/site-packages/tensorflow/python/framework/errors_impl.py in raise_exception_on_not_ok_status()
#     468           compat.as_text(pywrap_tensorflow.TF_Message(status)),
# --> 469           pywrap_tensorflow.TF_GetCode(status))
#     470   finally:
#
# ResourceExhaustedError: image_classification.data-00000-of-00001.tempstate4450044098038241185
# 	 [[Node: save/SaveV2 = SaveV2[dtypes=[DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT], _device="/job:localhost/replica:0/task:0/cpu:0"](_recv_save/Const_0, save/SaveV2/tensor_names, save/SaveV2/shape_and_slices, Variable/_33, Variable/Adam/_35, Variable/Adam_1/_37, Variable_1/_39, Variable_1/Adam/_41, Variable_1/Adam_1/_43, Variable_10/_45, Variable_11/_47, Variable_2/_49, Variable_2/Adam/_51, Variable_2/Adam_1/_53, Variable_3/_55, Variable_3/Adam/_57, Variable_3/Adam_1/_59, Variable_4/_61, Variable_4/Adam/_63, Variable_4/Adam_1/_65, Variable_5/_67, Variable_5/Adam/_69, Variable_5/Adam_1/_71, Variable_6/_73, Variable_7/_75, Variable_8/_77, Variable_9/_79, beta1_power/_81, beta2_power/_83)]]
#
# During handling of the above exception, another exception occurred:
#
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-17-9df3032ebe9d> in <module>()
#      21     # Save Model
#      22     saver = tf.train.Saver()
# ---> 23     save_path = saver.save(sess, save_model_path)
#
# /home/carnd/anaconda3/envs/dl/lib/python3.5/site-packages/tensorflow/python/training/saver.py in save(self, sess, save_path, global_step, latest_filename, meta_graph_suffix, write_meta_graph, write_state)
#    1372       model_checkpoint_path = sess.run(
#    1373           self.saver_def.save_tensor_name,
# -> 1374           {self.saver_def.filename_tensor_name: checkpoint_file})
#    1375       model_checkpoint_path = compat.as_str(model_checkpoint_path)
#    1376       if write_state:
#
# /home/carnd/anaconda3/envs/dl/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/carnd/anaconda3/envs/dl/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# /home/carnd/anaconda3/envs/dl/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /home/carnd/anaconda3/envs/dl/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1033         except KeyError:
#    1034           pass
# -> 1035       raise type(e)(node_def, op, message)
#    1036
#    1037   def _extend_graph(self):
#
# ResourceExhaustedError: image_classification.data-00000-of-00001.tempstate4450044098038241185
# 	 [[Node: save/SaveV2 = SaveV2[dtypes=[DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT], _device="/job:localhost/replica:0/task:0/cpu:0"](_recv_save/Const_0, save/SaveV2/tensor_names, save/SaveV2/shape_and_slices, Variable/_33, Variable/Adam/_35, Variable/Adam_1/_37, Variable_1/_39, Variable_1/Adam/_41, Variable_1/Adam_1/_43, Variable_10/_45, Variable_11/_47, Variable_2/_49, Variable_2/Adam/_51, Variable_2/Adam_1/_53, Variable_3/_55, Variable_3/Adam/_57, Variable_3/Adam_1/_59, Variable_4/_61, Variable_4/Adam/_63, Variable_4/Adam_1/_65, Variable_5/_67, Variable_5/Adam/_69, Variable_5/Adam_1/_71, Variable_6/_73, Variable_7/_75, Variable_8/_77, Variable_9/_79, beta1_power/_81, beta2_power/_83)]]
#
# Caused by op 'save/SaveV2', defined at:
#   File "/home/carnd/anaconda3/envs/dl/lib/python3.5/runpy.py", line 184, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/carnd/anaconda3/envs/dl/lib/python3.5/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/carnd/anaconda3/envs/dl/lib/python3.5/site-packages/ipykernel/__main__.py", line 3, in <module>
#     app.launch_new_instance()
#   File "/home/carnd/anaconda3/envs/dl/lib/python3.5/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/carnd/anaconda3/envs/dl/lib/python3.5/site-packages/ipykernel/kernelapp.py", line 474, in start
#     ioloop.IOLoop.instance().start()
#   File "/home/carnd/anaconda3/envs/dl/lib/python3.5/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/home/carnd/anaconda3/envs/dl/lib/python3.5/site-packages/tornado/ioloop.py", line 887, in start
#     handler_func(fd_obj, events)
#   File "/home/carnd/anaconda3/envs/dl/lib/python3.5/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/carnd/anaconda3/envs/dl/lib/python3.5/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/home/carnd/anaconda3/envs/dl/lib/python3.5/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/carnd/anaconda3/envs/dl/lib/python3.5/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/carnd/anaconda3/envs/dl/lib/python3.5/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/carnd/anaconda3/envs/dl/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 276, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/carnd/anaconda3/envs/dl/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 228, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/carnd/anaconda3/envs/dl/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 390, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/carnd/anaconda3/envs/dl/lib/python3.5/site-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/carnd/anaconda3/envs/dl/lib/python3.5/site-packages/ipykernel/zmqshell.py", line 501, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/carnd/anaconda3/envs/dl/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2717, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/carnd/anaconda3/envs/dl/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2821, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/carnd/anaconda3/envs/dl/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2881, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-17-9df3032ebe9d>", line 22, in <module>
#     saver = tf.train.Saver()
#   File "/home/carnd/anaconda3/envs/dl/lib/python3.5/site-packages/tensorflow/python/training/saver.py", line 1051, in __init__
#     self.build()
#   File "/home/carnd/anaconda3/envs/dl/lib/python3.5/site-packages/tensorflow/python/training/saver.py", line 1081, in build
#     restore_sequentially=self._restore_sequentially)
#   File "/home/carnd/anaconda3/envs/dl/lib/python3.5/site-packages/tensorflow/python/training/saver.py", line 673, in build
#     save_tensor = self._AddSaveOps(filename_tensor, saveables)
#   File "/home/carnd/anaconda3/envs/dl/lib/python3.5/site-packages/tensorflow/python/training/saver.py", line 271, in _AddSaveOps
#     save = self.save_op(filename_tensor, saveables)
#   File "/home/carnd/anaconda3/envs/dl/lib/python3.5/site-packages/tensorflow/python/training/saver.py", line 214, in save_op
#     tensors)
#   File "/home/carnd/anaconda3/envs/dl/lib/python3.5/site-packages/tensorflow/python/ops/gen_io_ops.py", line 779, in save_v2
#     tensors=tensors, name=name)
#   File "/home/carnd/anaconda3/envs/dl/lib/python3.5/site-packages/tensorflow/python/framework/op_def_library.py", line 763, in apply_op
#     op_def=op_def)
#   File "/home/carnd/anaconda3/envs/dl/lib/python3.5/site-packages/tensorflow/python/framework/ops.py", line 2395, in create_op
#     original_op=self._default_original_op, op_def=op_def)
#   File "/home/carnd/anaconda3/envs/dl/lib/python3.5/site-packages/tensorflow/python/framework/ops.py", line 1264, in __init__
#     self._traceback = _extract_stack()
#
# ResourceExhaustedError (see above for traceback): image_classification.data-00000-of-00001.tempstate4450044098038241185
# 	 [[Node: save/SaveV2 = SaveV2[dtypes=[DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT], _device="/job:localhost/replica:0/task:0/cpu:0"](_recv_save/Const_0, save/SaveV2/tensor_names, save/SaveV2/shape_and_slices, Variable/_33, Variable/Adam/_35, Variable/Adam_1/_37, Variable_1/_39, Variable_1/Adam/_41, Variable_1/Adam_1/_43, Variable_10/_45, Variable_11/_47, Variable_2/_49, Variable_2/Adam/_51, Variable_2/Adam_1/_53, Variable_3/_55, Variable_3/Adam/_57, Variable_3/Adam_1/_59, Variable_4/_61, Variable_4/Adam/_63, Variable_4/Adam_1/_65, Variable_5/_67, Variable_5/Adam/_69, Variable_5/Adam_1/_71, Variable_6/_73, Variable_7/_75, Variable_8/_77, Variable_9/_79, beta1_power/_81, beta2_power/_83)]]

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-13-46737803360c> in <module>()
#      61
#      62
# ---> 63 test_model()
#
# <ipython-input-13-46737803360c> in test_model()
#      31     with tf.Session(graph=loaded_graph) as sess:
#      32         # Load model
# ---> 33         loader = tf.train.import_meta_graph(save_model_path + '.meta')
#      34         loader.restore(sess, save_model_path)
#      35
#
# /home/carnd/anaconda3/envs/dl/lib/python3.5/site-packages/tensorflow/python/training/saver.py in import_meta_graph(meta_graph_or_file, clear_devices, import_scope, **kwargs)
#    1568   """
#    1569   if not isinstance(meta_graph_or_file, meta_graph_pb2.MetaGraphDef):
# -> 1570     meta_graph_def = meta_graph.read_meta_graph_file(meta_graph_or_file)
#    1571   else:
#    1572     meta_graph_def = meta_graph_or_file
#
# /home/carnd/anaconda3/envs/dl/lib/python3.5/site-packages/tensorflow/python/framework/meta_graph.py in read_meta_graph_file(filename)
#     400   meta_graph_def = meta_graph_pb2.MetaGraphDef()
#     401   if not file_io.file_exists(filename):
# --> 402     raise IOError("File %s does not exist." % filename)
#     403   # First try to read it as a binary file.
#     404   file_content = file_io.read_file_to_string(filename)
#
# OSError: File ./image_classification.meta does not exist.

# %% [markdown]
# ## Why 50-70% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 70%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
